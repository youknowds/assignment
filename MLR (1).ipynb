# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
plt.rcParams['axes.unicode_minus'] = False

# %%
import pandas as pd

df = pd.read_excel("C:/Users/kimso/Desktop/한시트에 2004-2020.xlsx")
df
# Out:
#          선거구    선거구 비율      인구 비       면적비     인구밀도비  1인당 지역내총생산비  1인당 지역총소득비  \
# 전국       243  1.000000  1.000000  1.000000  1.000000     1.000000    1.000000
# 서울특별시     48  0.197531  0.221732  0.006070  0.452190     0.070738    0.088265
# 부산광역시     18  0.074074  0.079404  0.007675  0.128415     0.045776    0.050282
# 대구광역시     12  0.049383  0.054738  0.008869  0.076312     0.039777    0.048991
# 인천광역시     12  0.049383  0.056268  0.010052  0.069974     0.055946    0.055566
# 광주광역시      7  0.028807  0.030323  0.005026  0.074674     0.041235    0.047816
# 대전광역시      6  0.024691  0.031268  0.005417  0.071542     0.047292    0.058735
# 울산광역시      6  0.024691  0.023449  0.010604  0.027396     0.132822    0.113875
# 경기도       49  0.201646  0.225095  0.101647  0.036827     0.055998    0.067446
# 강원도        8  0.032922  0.028186  0.166667  0.000296     0.051227    0.049455
# 충청북도       8  0.032922  0.026279  0.074560  0.009257     0.061125    0.056649
# ...

# %%
df_use=df.drop(['전국'])
df_use
# Out:
#          선거구    선거구 비율      인구 비       면적비     인구밀도비  1인당 지역내총생산비  1인당 지역총소득비  \
# 서울특별시     48  0.197531  0.221732  0.006070  0.452190     0.070738    0.088265
# 부산광역시     18  0.074074  0.079404  0.007675  0.128415     0.045776    0.050282
# 대구광역시     12  0.049383  0.054738  0.008869  0.076312     0.039777    0.048991
# 인천광역시     12  0.049383  0.056268  0.010052  0.069974     0.055946    0.055566
# 광주광역시      7  0.028807  0.030323  0.005026  0.074674     0.041235    0.047816
# 대전광역시      6  0.024691  0.031268  0.005417  0.071542     0.047292    0.058735
# 울산광역시      6  0.024691  0.023449  0.010604  0.027396     0.132822    0.113875
# 경기도       49  0.201646  0.225095  0.101647  0.036827     0.055998    0.067446
# 강원도        8  0.032922  0.028186  0.166667  0.000296     0.051227    0.049455
# 충청북도       8  0.032922  0.026279  0.074560  0.009257     0.061125    0.056649
# 충청남도      10  0.041152  0.034107  0.086278  0.009039     0.084052    0.069285
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(rc={'figure.figsize':(10,8)})
plt.hist(df_use['선거구'],bins=5,color='salmon')
plt.xlabel("number of constituency")
plt.show()

# %%
plt.figure(figsize=(10,10))
correlation_matrix=df_use.corr().round(3)
sns.heatmap(data=correlation_matrix,annot=True, cmap='bwr')

# %%
sns.set_style('darkgrid')
fig,axs=plt.subplots(ncols=3)
sns.regplot(x='인구밀도비',y='선거구 비율',data=df_use,ax=axs[0])
sns.regplot(x='1인당 민간소비비',y='선거구 비율',data=df_use,ax=axs[1])
sns.regplot(x='인구 비',y='선거구 비율',data=df_use,ax=axs[2])

# %%
import numpy as np

x_population=df_use['인구 비']
y_district=df_use['선거구 비율']

x_population=np.array(x_population).reshape(-1,1)

print(x_population.shape)
print(y_district.shape)
# Out:
# (81, 1)
# (81,)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = \
                    train_test_split(x_population,y_district,test_size=0.2,random_state=13)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (64, 1)
# (17, 1)
# (64,)
# (17,)

# %%
from sklearn.linear_model import LinearRegression

reg=LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
from sklearn.metrics import mean_squared_error

y_train_predict=reg.predict(x_train)
rmse=(np.sqrt(mean_squared_error(y_train,y_train_predict)))

print("The model performance for training set")
print("RMSE is",rmse)
# Out:
# The model performance for training set
# RMSE is 0.005768893913979397

# %%
y_test_predict=reg.predict(x_test)
rmse=(np.sqrt(mean_squared_error(y_test,y_test_predict)))

print("The model performance for test set")
print("RMSE is",rmse)
# Out:
# The model performance for test set
# RMSE is 0.005176751776128774

# %%
prediction_space=np.linspace(min(x_population),max(x_population)).reshape(-1,1)
plt.scatter(x_population,y_district)
plt.plot(prediction_space, reg.predict(prediction_space), color='black',linewidth=3)
plt.ylabel("number of constituency")
plt.xlabel("population")
plt.show()

# %%
df_use=df_use.drop('선거구',axis=1)
x=df_use.drop('선거구 비율',axis=1)
y=df_use['선거구 비율']

x_train, x_test, y_train, y_test = \
                    train_test_split(x,y,test_size=0.2,random_state=13)
    
reg_all=LinearRegression()
reg_all.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y_train_predict=reg_all.predict(x_train)
rmse=(np.sqrt(mean_squared_error(y_train,y_train_predict)))

print("The model performance for training set")
print("RMSE is",rmse)
# Out:
# The model performance for training set
# RMSE is 0.004477620903550006

# %%
y_test_predict=reg_all.predict(x_test)
rmse=(np.sqrt(mean_squared_error(y_test,y_test_predict)))

print("The model performance for test set")
print("RMSE is",rmse)
# Out:
# The model performance for test set
# RMSE is 0.005299308777388109

# %%
plt.scatter(y_test,y_test_predict)
plt.xlabel("Actual constituency")
plt.ylabel("Predicted constituency")
plt.title("Actual Prices vs Predicted prices")
plt.plot([0,0.5],[0,0.5],'r')

# %%
seoul=[[0.188699658915374,0.006027217,0.452361285,0.075854516, 0.0895222651,0.07571562, 0.08068192, 70]]
seoul_predict=reg_all.predict(seoul)
seoul_predict
# Out:
# array([0.18178704])

# %%
busan=[[0.065102104, 0.007671004, 0.122623579, 0.047035963, 0.0529860072, 0.06155316, 0.06661847,70]]
busan_predict=reg_all.predict(busan)
busan_predict
# Out:
# array([0.06307495])

# %%
daegu=[[0.046269305, 0.008806711, 0.075911994, 0.040657484, 0.0500689648, 0.06122508, 0.06507645,70]]
daegu_predict=reg_all.predict(daegu)
daegu_predict
# Out:
# array([0.04372132])

# %%
incheon=[[0.057686461, 0.010589970, 0.078706450, 0.054299250, 0.0594791437, 0.06021855, 0.06019387,70]]
incheon_predict=reg_all.predict(incheon)
incheon_predict
# Out:
# array([0.05489986])

# %%
gwangju=[[0.027335105, 0.004991134, 0.079132103, 0.046044727, 0.0541285985, 0.06346151, 0.06542076, 70]]
gwangju_predict=reg_all.predict(gwangju)
gwangju_predict
# Out:
# array([0.02786124])

# %%
daejeon=[[0.027859220, 0.005379665, 0.074824682, 0.048283048, 0.0549160727, 0.06554869, 0.06518996,70]]
daejeon_predict=reg_all.predict(daejeon)
daejeon_predict
# Out:
# array([0.03053073])

# %%
ulsan=[[0.021379078, 0.010580008, 0.029196725, 0.131385061, 0.1012863159, 0.07446037, 0.06981663,70]]
ulsan_predict=reg_all.predict(ulsan)
ulsan_predict
# Out:
# array([0.02757897])

# %%
gyeonggi=[[0.263394004, 0.101496344, 0.037496146, 0.010787685, 0.0510333331, 0.06422765, 0.04525892,70]]
gyeonggi_predict=reg_all.predict(gyeonggi)
gyeonggi_predict
# Out:
# array([0.24178547])

# %%
kangwon=[[0.030276067, 0.167646297, 0.002609376, 0.053287271, 0.0508861030, 0.05906385, 0.06077164,70]]
kangwon_predict=reg_all.predict(kangwon)
kangwon_predict
# Out:
# array([0.03775968])

# %%
chungbuk=[[0.031206626, 0.073801032, 0.006109639, 0.068423553, 0.0609918058, 0.05947370, 0.05907370,70]]
chungbuk_predict=reg_all.predict(chungbuk)
chungbuk_predict
# Out:
# array([0.03465592])

# %%
chungnam=[[0.041484617, 0.081980115, 0.007311554, 0.097856749, 0.0760800902, 0.05933114, 0.06054838,70]]
chungnam_predict=reg_all.predict(chungnam)
chungnam_predict
# Out:
# array([0.04420415])

# %%
jeonbuk=[[ 0.034593651, 0.080386140, 0.006217938, 0.050800133, 0.0494589884, 0.05854733, 0.05896682,70]]
jeonbuk_predict=reg_all.predict(jeonbuk)
jeonbuk_predict
# Out:
# array([0.03851383])

# %%
jeonnam=[[0.035801308, 0.122975154, 0.004206420, 0.079398252, 0.0657392637, 0.05776761, 0.05841691,70]]
jeonnam_predict=reg_all.predict(jeonnam)
jeonnam_predict
# Out:
# array([0.04074986])

# %%
gyeongbuk=[[0.051247751, 0.189613262, 0.003905146, 0.078195020, 0.0663770805, 0.05877414, 0.05864969, 70]]
gyeongbuk_predict=reg_all.predict(gyeongbuk)
gyeongbuk_predict
# Out:
# array([0.05740548])

# %%
gyeongnam=[[0.064288871, 0.105003088, 0.008846365, 0.063928296, 0.0599117844, 0.06131274, 0.06090768, 70]]
gyeongnam_predict=reg_all.predict(gyeongnam)
gyeongnam_predict
# Out:
# array([0.06533536])

# %%
jeju=[[0.013376180, 0.018430333, 0.010486488, 0.053763189, 0.0571334172, 0.05931810, 0.06440699, 70]]
jeju_predict=reg_all.predict(jeju)
jeju_predict
# Out:
# array([0.00970741])

# %%
round(float(seoul_predict*253))
# Out:
# 46

# %%
round(float(busan_predict*253))
# Out:
# 16

# %%
round(float(daegu_predict*253))
# Out:
# 11

# %%
round(float(incheon_predict*253))
# Out:
# 14

# %%
round(float(gwangju_predict*253))
# Out:
# 7

# %%
round(float(daejeon_predict*253))
# Out:
# 8

# %%
round(float(ulsan_predict*253))
# Out:
# 7

# %%
round(float(gyeonggi_predict*253))
# Out:
# 61

# %%
round(float(kangwon_predict*253))
# Out:
# 10

# %%
round(float(chungbuk_predict*253))
# Out:
# 9

# %%
round(float(chungnam_predict*253))
# Out:
# 11

# %%
round(float(jeonbuk_predict*253))
# Out:
# 10

# %%
round(float(jeonnam_predict*253))
# Out:
# 10

# %%
round(float(gyeongbuk_predict*253))
# Out:
# 15

# %%
round(float(gyeongnam_predict*253))
# Out:
# 17

# %%
round(float(jeju_predict*253))
# Out:
# 2
