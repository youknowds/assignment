# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
plt.rcParams['axes.unicode_minus'] = False

# %%
import pandas as pd

df_2008 = pd.read_excel("C:/Users/kimso/Desktop/capstone_data.xlsx", "2008 18대 총선")
df_2008
# Out:
#          선거구    선거구 비율        인구  면적(㎢)     인구밀도(명/㎢)  1인당 지역내총생산  1인당 지역총소득  \
# 전국       245  1.000000  50137634  99828    502.240193       23637      23643
# 서울특별시     48  0.195918  10456034    605  17282.700826       27894      31939
# 부산광역시     18  0.073469   3596063    766   4694.599217       18167      18716
# 대구광역시     12  0.048980   2512604    884   2842.312217       15049      16826
# 인천광역시     12  0.048980   2741217   1010   2714.076238       19970      20358
# 광주광역시      8  0.032653   1434625    501   2863.522954       16525      17884
# 대전광역시      6  0.024490   1495048    540   2768.607407       17426      18467
# 울산광역시      6  0.024490   1126879   1058   1065.103025       48794      41758
# 경기도       51  0.208163  11292264  10134   1114.294849       20863      22099
# 강원도        8  0.032653   1521467  16614    150.134892       19593      17844
# 충청북도       8  0.032653   1542287   7433     92.830565       22378      19290
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

df_2008_use=df_2008.drop(['전국'])

sns.set(rc={'figure.figsize':(10,8)})
plt.hist(df_2008_use['선거구'],bins=5)
plt.xlabel("number of constituency")
plt.show()

# %%
plt.figure(figsize=(10, 10))
correlation_matrix=df_2008_use.corr().round(3)
sns.heatmap(data=correlation_matrix,annot=True, cmap='bwr')

# %%
sns.set_style('darkgrid')
fig,axs=plt.subplots(ncols=3)
sns.regplot(x='인구밀도(명/㎢)',y='선거구 비율',data=df_2008_use,ax=axs[0])
sns.regplot(x='1인당 민간소비',y='선거구 비율',data=df_2008_use,ax=axs[1])
sns.regplot(x='인구',y='선거구 비율',data=df_2008_use,ax=axs[2])
