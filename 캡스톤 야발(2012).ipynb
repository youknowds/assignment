# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
plt.rcParams['axes.unicode_minus'] = False

# %%
import pandas as pd

df_2012 = pd.read_excel("C:/Users/kimso/Desktop/capstone_data.xlsx", "2012 19대 총선")
df_2012
# Out:
#          선거구    선거구 비율        인구      면적(㎢)  인구밀도(명/㎢)  1인당 지역내총생산  1인당 지역총소득  \
# 전국       246  1.000000  50734284  100261.78     508.15       28793      29093
# 서울특별시     48  0.195122  10249679     605.20   16846.20       33312      39215
# 부산광역시     18  0.073171   3550963     769.86    4596.27       20554      22742
# 대구광역시     12  0.048780   2507271     883.63    2835.63       18078      21093
# 인천광역시     12  0.048780   2801274    1032.41    2754.70       23770      24491
# 광주광역시      8  0.032520   1463464     501.18    2931.51       19799      21798
# 대전광역시      6  0.024390   1515603     540.14    2822.57       21347      23540
# 울산광역시      6  0.024390   1135494    1060.19    1082.12       62242      49348
# 경기도       52  0.211382  11937415   10171.10    1188.99       26007      28906
# 강원도        9  0.036585   1536448   16873.57      91.19       22973      21169
# 충청북도       8  0.032520   1562903    7406.24     211.39       29177      24875
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

df_2012_use=df_2012.drop(['전국'])

sns.set(rc={'figure.figsize':(10,8)})
plt.hist(df_2012_use['선거구'],bins=5,color='salmon')
plt.xlabel("number of constituency")
plt.show()

# %%
df_2012_use=df_2012.drop(['전국'])
plt.figure(figsize=(10,10))
correlation_matrix=df_2012_use.corr().round(3)
sns.heatmap(data=correlation_matrix,annot=True, cmap='bwr')

# %%
sns.set_style('darkgrid')
fig,axs=plt.subplots(ncols=3)
sns.regplot(x='인구밀도(명/㎢)',y='선거구 비율',data=df_2012_use,ax=axs[0])
sns.regplot(x='1인당 민간소비',y='선거구 비율',data=df_2012_use,ax=axs[1])
sns.regplot(x='인구',y='선거구 비율',data=df_2012_use,ax=axs[2])
