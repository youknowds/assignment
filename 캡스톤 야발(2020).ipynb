# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
plt.rcParams['axes.unicode_minus'] = False

# %%
import pandas as pd

df_2020 = pd.read_excel("C:/Users/kimso/Desktop/capstone_data.xlsx", "2020 21대 총선")
df_2020
# Out:
#          선거구    선거구 비율        인구   면적(㎢)  인구밀도(명/㎢)    1인당 지역내총생산  \
# 전국       253  1.000000  51842524  100378     516.47  37059.533843
# 서울특별시     49  0.193676   9726787     605   16077.33  43169.300993
# 부산광역시     18  0.071146   3408347     770    4426.42  26812.816654
# 대구광역시     12  0.047431   2431523     884    2750.59  23232.494729
# 인천광역시     13  0.051383   2950972    1063    2776.08  31086.501604
# 광주광역시      8  0.031621   1456096     501    2906.38  26231.575880
# 대전광역시      7  0.027668   1471650     540    2725.28  27558.814461
# 울산광역시      6  0.023715   1144098    1062    1077.31  74671.574892
# 세종특별자치시    2  0.007905    345216     465     742.40  26126.476190
# 경기도       59  0.233202  13311254   10188    1306.56  34193.620474
# 강원도        8  0.031621   1537780   16828      91.38  30411.653476
# 충청북도       8  0.031621   1596613    7408     215.53  38874.456073
# 충청남도      11  0.043478   2118457    8229     257.44  55322.709702
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

df_2020_use=df_2020.drop(['전국'])

sns.set(rc={'figure.figsize':(10,8)})
plt.hist(df_2020_use['선거구'],bins=5,color='salmon')
plt.xlabel("number of constituency")
plt.show()

# %%
df_2020_use=df_2020.drop(['전국'])
plt.figure(figsize=(10,10))
correlation_matrix=df_2020_use.corr().round(3)
sns.heatmap(data=correlation_matrix,annot=True, cmap='bwr')

# %%
sns.set_style('darkgrid')
fig,axs=plt.subplots(ncols=3)
sns.regplot(x='인구밀도(명/㎢)',y='선거구 비율',data=df_2020_use,ax=axs[0])
sns.regplot(x='1인당 민간소비',y='선거구 비율',data=df_2020_use,ax=axs[1])
sns.regplot(x='인구',y='선거구 비율',data=df_2020_use,ax=axs[2])
